# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
data=pd.read_csv("TSLA.csv",sep="\t")

# %%
data.isnull().sum()
# Out:
# Date            0
# Open            0
# High            0
# Low             0
# Close           0
# Volume          0
# Dividends       0
# Stock Splits    0
# dtype: int64

# %%
univariate_data=data[["Date","Close"]]

# %%
univariate_data["Date"]=pd.to_datetime(univariate_data["Date"])

# %%
univariate_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 758 entries, 0 to 757
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    758 non-null    datetime64[ns]
#  1   Close   758 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 12.0 KB

# %%
stock_data=univariate_data.set_index("Date")

# %%
stock_data.head()
# Out:
#                 Close
# Date
# 2019-05-21  41.015999
# 2019-05-22  38.546001
# 2019-05-23  39.098000
# 2019-05-24  38.125999
# 2019-05-28  37.740002

# %%
stock_data.describe()
# Out:
#              Close
# count   758.000000
# mean    634.113940
# std     375.846585
# min      35.793999
# 25%     145.416004
# 50%     730.169983
# 75%     921.789993
# max    1229.910034

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.figure(figsize=(8,8))
plt.plot(stock_data.Close)

# %%
plt.hist(stock_data.Close)
# Out:
# (array([199.,  11.,   0.,   0.,  37., 161., 121.,  81., 118.,  30.]),
#  array([  35.79399872,  155.20560226,  274.61720581,  394.02880936,
#          513.4404129 ,  632.85201645,  752.26362   ,  871.67522354,
#          991.08682709, 1110.49843063, 1229.91003418]),
#  <BarContainer object of 10 artists>)

# %%
plt.style.use('ggplot')
plt.figure(figsize=(18,8))
plt.grid(True)
plt.xlabel("Dates",fontsize=20)
plt.xticks(fontsize=15)
plt.ylabel("close price",fontsize=20)
plt.yticks(fontsize = 15) 
plt.plot(stock_data["Close"])
plt.title("tesla stock closing price",fontsize=30)
plt.show()

# %%
plt.style.use('ggplot')
plt.figure(figsize=(18,8))
plt.grid(True)
plt.xlabel("Dates",fontsize=20)
plt.xticks(fontsize=15)
plt.ylabel("close price",fontsize=20)
plt.yticks(fontsize = 15) 
plt.hist(stock_data['Close'], linewidth = 3, color = 'blue')
plt.title("tesla stock closing price",fontsize=30)
plt.show()

# %%
df_close = stock_data['Close'] 
df_close.plot(kind='kde',figsize = (18,8), linewidth= 3) 
plt.xticks(fontsize = 15)
plt.grid("both")
plt.ylabel('Density', fontsize = 20)
plt.yticks(fontsize = 15)
plt.show()

# %%
rolmean=stock_data["Close"].rolling(48).mean()

# %%
stock_data["Close"].rolling(3).std()
# Out:
# Date
# 2019-05-21          NaN
# 2019-05-22          NaN
# 2019-05-23     1.296425
# 2019-05-24     0.487492
# 2019-05-28     0.699754
#                 ...
# 2022-05-16    25.125547
# 2022-05-17    24.136242
# 2022-05-18    26.714694
# 2022-05-19    30.019958
# 2022-05-20    26.394268
# Name: Close, Length: 758, dtype: float64

# %%
plt.figure(figsize=(18,8))
plt.plot(stock_data.Close)
plt.plot(rolmean)
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller
adf=adfuller(stock_data["Close"])

# %%
adf # second value is used for checking stationary or not
# Out:
# (-1.797721349971683,
#  0.3815935655171208,
#  8,
#  749,
#  {'1%': -3.439110818166223,
#   '5%': -2.8654065210185795,
#   '10%': -2.568828945705979},
#  7390.350417820852)

# %%
pd.Series(adf[0:4],index=["test stats","p-value","lag","data point"])
# Out:
# test stats     -1.797721
# p-value         0.381594
# lag             8.000000
# data point    749.000000
# dtype: float64

# %%
#Test for staionarity
def test_stationarity(timeseries):
    # Determing rolling statistics
    rolmean = timeseries.rolling(48).mean() # rolling mean
    rolstd = timeseries.rolling(48).std() # rolling standard deviation
    # Plot rolling statistics:
    plt.figure(figsize = (18,8))
    plt.grid('both')
    plt.plot(timeseries, color='blue',label='Original', linewidth = 3)
    plt.plot(rolmean, color='red', label='Rolling Mean',linewidth = 3)
    plt.plot(rolstd, color='black', label = 'Rolling Std',linewidth = 4)
    plt.legend(loc='best', fontsize = 20, shadow=True,facecolor='lightpink',edgecolor = 'k')
    plt.title('Rolling Mean and Standard Deviation', fontsize = 25)
    plt.xticks(fontsize = 15)
    plt.yticks(fontsize = 15)
    plt.show(block=False)
    
    print("Results of dickey fuller test")
    adft = adfuller(timeseries,autolag='AIC')
    # output for dft will give us without defining what the values are.
    # hence we manually write what values does it explains using a for loop
    output = pd.Series(adft[0:4],index=['Test Statistics','p-value','No. of lags used','Number of observations used'])
    for key,values in adft[4].items():
        output['critical value (%s)'%key] =  values
    print(output)

# %%
test_stationarity(stock_data.Close)
# Out:
# Results of dickey fuller test
# Test Statistics                 -1.797721
# p-value                          0.381594
# No. of lags used                 8.000000
# Number of observations used    749.000000
# critical value (1%)             -3.439111
# critical value (5%)             -2.865407
# critical value (10%)            -2.568829
# dtype: float64

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
result=seasonal_decompose(stock_data["Close"],model="multiplicative",period=30)

# %%
plt.figure(figsize=(18,8))
fig=result.plot()
fig.set_size_inches(17,10)

# %%
result.resid
# Out:
# Date
# 2019-05-21   NaN
# 2019-05-22   NaN
# 2019-05-23   NaN
# 2019-05-24   NaN
# 2019-05-28   NaN
#               ..
# 2022-05-16   NaN
# 2022-05-17   NaN
# 2022-05-18   NaN
# 2022-05-19   NaN
# 2022-05-20   NaN
# Name: resid, Length: 758, dtype: float64

# %%
result.seasonal
# Out:
# Date
# 2019-05-21    1.043023
# 2019-05-22    1.044101
# 2019-05-23    1.031907
# 2019-05-24    1.031905
# 2019-05-28    1.019545
#                 ...
# 2022-05-16    1.031905
# 2022-05-17    1.019545
# 2022-05-18    1.012320
# 2022-05-19    1.007487
# 2022-05-20    1.024621
# Name: seasonal, Length: 758, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(20, 10))
# Plot the box plot
ax.boxplot(stock_data["Close"])
# Set the x-axis label
ax.set_xlabel('Variables')
# Set the y-axis label
ax.set_ylabel('Values')
# Set the title
ax.set_title('Box plot')
# Show the plot
plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
plot_acf(stock_data.Close)
plot_pacf(stock_data.Close)

# %% [markdown]
# # Preprocessing of the data
# 1.fill the miss(here not required)
#
# 2.convert data into the stationary time series
#
# 3.if necessary then normalize the data(here not required)
#
# 4.the data into train and test
#
# 5.clean the data by removing the outlier(here not required)

# %%
df_close=stock_data["Close"]

# %%
diff_1=df_close.diff().dropna()

# %%
test_stationarity(diff_1)
# Out:
# Results of dickey fuller test
# Test Statistics               -9.779462e+00
# p-value                        6.794413e-17
# No. of lags used               7.000000e+00
# Number of observations used    7.490000e+02
# critical value (1%)           -3.439111e+00
# critical value (5%)           -2.865407e+00
# critical value (10%)          -2.568829e+00
# dtype: float64

# %%
train_data=df_close[0:-60]
test_data=df_close[-60:]

# %%
plt.figure(figsize=(18,8))
plt.grid(True)
plt.xlabel('Dates', fontsize = 20)
plt.ylabel('Closing Prices', fontsize = 20)
plt.xticks(fontsize = 15)
plt.xticks(fontsize = 15)
plt.plot(train_data, 'green', label='Train data', linewidth = 5)
plt.plot(test_data, 'blue', label='Test data', linewidth = 5)
plt.legend(fontsize = 20, shadow=True,facecolor='lightpink',edgecolor = 'k')

# %%
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
history=[x for x in train_data]

# %%
history
# Out:
# [41.01599884033203,
#  38.54600143432617,
#  39.09799957275391,
#  38.1259994506836,
#  37.7400016784668,
#  37.97200012207031,
#  37.64400100708008,
#  37.03200149536133,
#  35.79399871826172,
#  38.720001220703125,
#  39.31800079345703,
#  41.18999862670898,
#  40.900001525878906,
#  42.57600021362305,
#  43.41999816894531,
#  41.85200119018555,
#  42.78200149536133,
#  42.98400115966797,
#  45.00600051879883,
#  44.948001861572266,
#  45.2859992980957,
#  43.92399978637695,
#  44.37200164794922,
#  44.72800064086914,
#  43.95199966430664,
#  43.854000091552734,
#  44.56800079345703,
#  44.69200134277344,
#  45.43399810791016,
#  44.90999984741211,
#  46.97999954223633,
#  46.619998931884766,
#  46.06800079345703,
#  46.012001037597656,
#  47.78400039672852,
#  47.720001220703125,
#  49.01599884033203,
#  50.70000076293945,
#  50.47600173950195,
#  50.97200012207031,
#  50.70800018310547,
#  51.63600158691406,
#  51.13600158691406,
#  52.03400039672852,
#  52.97600173950195,
#  45.76399993896485,
#  45.608001708984375,
#  47.15399932861328,
#  48.45199966430664,
#  48.321998596191406,
#  46.77000045776367,
#  46.86800003051758,
#  45.66400146484375,
#  46.150001525878906,
#  46.68399810791016,
#  47.65999984741211,
#  47.00199890136719,
#  45.80199813842773,
#  47.0,
#  43.92399978637695,
#  43.12799835205078,
#  43.98799896240234,
#  45.36600112915039,
#  45.172000885009766,
#  44.16600036621094,
#  44.43000030517578,
#  42.27999877929688,
#  43.0,
#  42.81600189208984,
#  43.11800003051758,
#  44.34199905395508,
#  45.12200164794922,
#  45.00199890136719,
#  44.13600158691406,
#  45.91600036621094,
#  45.4900016784668,
#  46.358001708984375,
#  47.108001708984375,
#  49.41999816894531,
#  49.17399978637695,
#  49.040000915527344,
#  48.5620002746582,
#  48.95800018310547,
#  48.698001861572266,
#  49.31999969482422,
#  48.124000549316406,
#  48.24599838256836,
#  44.641998291015625,
#  45.7400016784668,
#  48.512001037597656,
#  48.42599868774414,
#  48.17399978637695,
#  48.9379997253418,
#  48.6259994506836,
#  46.60599899291992,
#  46.2859992980957,
#  47.54399871826172,
#  48.0099983215332,
#  48.90599822998047,
#  48.948001861572266,
#  49.57799911499024,
#  51.391998291015625,
#  51.57799911499024,
#  51.95000076293945,
#  52.39400100708008,
#  51.38999938964844,
#  50.70000076293945,
#  51.11600112915039,
#  50.93600082397461,
#  59.93600082397461,
#  65.6259994506836,
#  65.54199981689453,
#  63.24399948120117,
#  63.00199890136719,
#  62.98400115966797,
#  62.6619987487793,
#  63.49399948120117,
#  63.44400024414063,
#  65.31600189208984,
#  67.10800170898438,
#  67.4280014038086,
#  69.01799774169922,
#  69.98600006103516,
#  69.22200012207031,
#  69.87000274658203,
#  70.43399810791016,
#  69.99800109863281,
#  71.90399932861328,
#  70.44400024414062,
#  70.96600341796875,
#  66.60800170898438,
#  67.26799774169922,
#  65.78399658203125,
#  66.25800323486328,
#  65.98799896240234,
#  66.9739990234375,
#  67.23999786376953,
#  66.60600280761719,
#  66.0739974975586,
#  67.1780014038086,
#  67.90599822998047,
#  69.76799774169922,
#  70.54000091552734,
#  71.93599700927734,
#  71.6780014038086,
#  76.30000305175781,
#  75.7979965209961,
#  78.62999725341797,
#  80.80799865722656,
#  81.11799621582031,
#  83.84400177001953,
#  85.05000305175781,
#  86.18800354003906,
#  86.07599639892578,
#  82.94000244140625,
#  83.66600036621094,
#  86.052001953125,
#  88.60199737548828,
#  90.30799865722656,
#  93.81199645996094,
#  98.4280014038086,
#  96.26799774169922,
#  95.62999725341795,
#  104.97200012207033,
#  107.58399963378906,
#  103.6999969482422,
#  102.697998046875,
#  102.0999984741211,
#  109.44000244140624,
#  113.91200256347656,
#  114.44000244140624,
#  112.96399688720705,
#  111.60399627685548,
#  113.37999725341795,
#  116.197998046875,
#  128.16200256347656,
#  130.11399841308594,
#  156.0,
#  177.41200256347656,
#  146.94000244140625,
#  149.79200744628906,
#  149.61399841308594,
#  154.25599670410156,
#  154.87600708007812,
#  153.45799255371094,
#  160.8000030517578,
#  160.00599670410156,
#  171.67999267578125,
#  183.48399353027344,
#  179.8820037841797,
#  180.1999969482422,
#  166.75799560546875,
#  159.98199462890625,
#  155.75999450683594,
#  135.8000030517578,
#  133.59800720214844,
#  148.7239990234375,
#  149.1020050048828,
#  149.89999389648438,
#  144.9080047607422,
#  140.6959991455078,
#  121.5999984741211,
#  129.0659942626953,
#  126.84600067138672,
#  112.11000061035156,
#  109.3239974975586,
#  89.01399993896484,
#  86.04000091552734,
#  72.24400329589844,
#  85.52799987792969,
#  653.3800048828125,
#  650.5999755859375,
#  644.219970703125,
#  646.219970703125,
#  660.5,
#  655.2899780273438,
#  649.260009765625,
#  643.3800048828125,
#  657.6199951171875,
#  644.780029296875,
#  646.97998046875,
#  677.3499755859375,
#  687.2000122070312,
#  709.6699829101562,
#  709.739990234375,
#  710.9199829101562,
#  714.6300048828125,
#  699.0999755859375,
#  713.760009765625,
#  709.989990234375,
#  707.8200073242188,
#  722.25,
#  717.1699829101562,
#  686.1699829101562,
#  665.7100219726562,
#  688.989990234375,
#  673.469970703125,
#  680.260009765625,
#  706.2999877929688,
#  708.489990234375,
#  711.2000122070312,
#  701.1599731445312,
#  711.9199829101562,
#  730.9099731445312,
#  735.719970703125,
#  734.0900268554688,
#  732.3900146484375,
#  733.5700073242188,
#  752.9199829101562,
#  753.8699951171875,
#  754.8599853515625,
#  736.27001953125,
#  743.0,
#  744.489990234375,
#  755.8300170898438,
#  756.989990234375,
#  759.489990234375,
#  730.1699829101562,
#  739.3800048828125,
#  751.9400024414062,
#  753.6400146484375,
#  774.3900146484375,
#  791.3599853515625,
#  777.5599975585938,
#  781.3099975585938,
#  775.47998046875,
#  775.219970703125,
#  781.530029296875,
#  780.5900268554688,
#  782.75,
#  793.6099853515625,
#  785.489990234375,
#  791.9400024414062,
#  805.719970703125,
#  811.0800170898438,
#  818.3200073242188,
#  843.030029296875,
#  870.1099853515625,
#  864.27001953125,
#  865.7999877929688,
#  894.0,
#  909.6799926757812,
#  1024.8599853515625,
#  1018.4299926757812,
#  1037.8599853515625,
#  1077.0400390625,
#  1114.0,
#  1208.5899658203125,
#  1172.0,
#  1213.8599853515625,
#  1229.9100341796875,
#  1222.0899658203125,
#  1162.93994140625,
#  1023.5,
#  1067.949951171875,
#  1063.510009765625,
#  1033.4200439453125,
#  1013.3900146484376,
#  1054.72998046875,
#  1089.010009765625,
#  1096.3800048828125,
#  1137.06005859375,
#  1156.8699951171875,
#  1109.030029296875,
#  1116.0,
#  1081.9200439453125,
#  1136.989990234375,
#  1144.760009765625,
#  1095.0,
#  1084.5999755859375,
#  1014.969970703125,
#  1009.010009765625,
#  1051.75,
#  1068.9599609375,
#  1003.7999877929688,
#  1017.030029296875,
#  966.4099731445312,
#  958.510009765625,
#  975.989990234375,
#  926.9199829101562,
#  932.5700073242188,
#  899.9400024414062,
#  938.530029296875,
#  1008.8699951171876,
#  1067.0,
#  1093.93994140625,
#  1088.469970703125,
#  1086.18994140625,
#  1070.3399658203125,
#  1056.780029296875,
#  1199.780029296875,
#  1149.5899658203125,
#  1088.1199951171875,
#  1064.699951171875,
#  1026.9599609375,
#  1058.1199951171875,
#  1064.4000244140625,
#  1106.219970703125,
#  1031.56005859375,
#  1049.6099853515625,
#  1030.510009765625,
#  995.6500244140624,
#  996.27001953125,
#  943.9000244140624,
#  930.0,
#  918.4000244140624,
#  937.4099731445312,
#  829.0999755859375,
#  846.3499755859375,
#  936.719970703125,
#  931.25,
#  905.6599731445312,
#  891.1400146484375,
#  923.3200073242188,
#  907.3400268554688,
#  922.0,
#  932.0,
#  904.5499877929688,
#  860.0,
#  875.760009765625,
#  922.4299926757812,
#  923.3900146484376,
#  876.3499755859375,
#  856.97998046875,
#  821.530029296875,
#  764.0399780273438,
#  800.77001953125,
#  809.8699951171875,
#  870.4299926757812,
#  864.3699951171875,
#  879.8900146484375,
#  839.2899780273438,
#  838.2899780273438,
#  804.5800170898438,
#  824.4000244140625,
#  858.969970703125,
#  838.2999877929688,
#  795.3499755859375,
#  766.3699951171875,
#  801.8900146484375,
#  840.22998046875,
#  871.5999755859375,
#  905.3900146484376,
#  921.1599731445312,
#  993.97998046875,
#  999.1099853515624,
#  1013.9199829101562,
#  1010.6400146484376,
#  1091.8399658203125,
#  1099.5699462890625,
#  1093.989990234375,
#  1077.5999755859375,
#  1084.5899658203125,
#  1145.449951171875,
#  1091.260009765625,
#  1045.760009765625,
#  1057.260009765625,
#  1025.489990234375,
#  975.9299926757812,
#  986.9500122070312,
#  1022.3699951171876,
#  985.0,
#  1004.2899780273438,
#  1028.1500244140625,
#  977.2000122070312,
#  1008.780029296875,
#  1005.0499877929688,
#  998.02001953125,
#  876.4199829101562,
#  881.510009765625,
#  877.510009765625,
#  870.760009765625,
#  902.9400024414062,
#  909.25,
#  952.6199951171876,
#  873.280029296875,
#  865.6500244140625,
#  787.1099853515625,
#  800.0399780273438,
#  734.0,
#  728.0,
#  769.5900268554688,
#  724.3699951171875,
#  761.6099853515625,
#  709.8099975585938,
#  709.4199829101562,
#  663.9000244140625,
#  793.530029296875,
#  839.8099975585938,
#  872.7899780273438,
#  854.6900024414062,
#  849.989990234375,
#  852.22998046875,
#  863.4199829101562,
#  849.4600219726562,
#  804.8200073242188,
#  811.6599731445312,
#  816.1199951171875,
#  796.219970703125,
#  798.1500244140625,
#  787.3800048828125,
#  781.2999877929688,
#  714.5,
#  698.8400268554688,
#  742.02001953125,
#  682.219970703125,
#  675.5,
#  718.4299926757812,
#  686.4400024414062,
#  653.2000122070312,
#  621.4400024414062,
#  597.9500122070312,
#  563.0,
#  673.5800170898438,
#  668.0599975585938,
#  699.5999755859375,
#  693.72998046875,
#  707.9400024414062,
#  676.8800048828125,
#  701.8099975585938,
#  653.1599731445312,
#  654.8699951171875,
#  670.0,
#  662.1599731445312,
#  630.27001953125,
#  640.3900146484375,
#  618.7100219726562,
#  611.2899780273438,
#  635.6199951171875,
#  667.9299926757812,
#  661.75,
#  691.0499877929688,
#  691.6199951171875,
#  670.969970703125,
#  683.7999877929688,
#  677.02001953125,
#  701.97998046875,
#  762.3200073242188,
#  732.22998046875,
#  738.8499755859375,
#  739.780029296875,
#  714.6300048828125,
#  718.989990234375,
#  744.1199951171875,
#  719.6900024414062,
#  729.4000244140625,
#  738.2000122070312,
#  704.739990234375,
#  694.4000244140625,
#  677.0,
#  709.4400024414062,
#  684.9000244140625,
#  673.5999755859375,
#  670.9400024414062,
#  663.5399780273438,
#  672.3699951171875,
#  629.0399780273438,
#  617.2000122070312,
#  589.8900146484375,
#  571.6900024414062,
#  589.739990234375,
#  576.8300170898438,
#  577.8699951171875,
#  563.4600219726562,
#  586.780029296875,
#  580.8800048828125,
#  606.4400024414062,
#  604.6900024414062,
#  619.1300048828125,
#  630.8499755859375,
#  625.219970703125,
#  623.9000244140625,
#  605.1199951171875,
#  572.8400268554688,
#  599.0499877929688,
#  605.1300048828125,
#  603.5900268554688,
#  598.780029296875,
#  610.1199951171875,
#  609.8900146484375,
#  617.6900024414062,
#  599.3599853515625,
#  604.8699951171875,
#  616.5999755859375,
#  623.3099975585938,
#  620.8300170898438,
#  623.7100219726562,
#  656.5700073242188,
#  679.8200073242188,
#  671.8699951171875,
#  688.719970703125,
#  680.760009765625,
#  679.7000122070312,
#  677.9199829101562,
#  678.9000244140625,
#  659.5800170898438,
#  644.6500244140625,
#  652.8099975585938,
#  656.9500122070312,
#  685.7000122070312,
#  668.5399780273438,
#  653.3800048828125,
#  650.5999755859375,
#  644.219970703125,
#  646.219970703125,
#  660.5,
#  655.2899780273438,
#  649.260009765625,
#  643.3800048828125,
#  657.6199951171875,
#  644.780029296875,
#  646.97998046875,
#  677.3499755859375,
#  687.2000122070312,
#  709.6699829101562,
#  709.739990234375,
#  710.9199829101562,
#  714.6300048828125,
#  699.0999755859375,
#  713.760009765625,
#  709.989990234375,
#  707.8200073242188,
#  722.25,
#  717.1699829101562,
#  686.1699829101562,
#  665.7100219726562,
#  688.989990234375,
#  673.469970703125,
#  680.260009765625,
#  706.2999877929688,
#  708.489990234375,
#  711.2000122070312,
#  701.1599731445312,
#  711.9199829101562,
#  730.9099731445312,
#  735.719970703125,
#  734.0900268554688,
#  732.3900146484375,
#  733.5700073242188,
#  752.9199829101562,
#  753.8699951171875,
#  754.8599853515625,
#  736.27001953125,
#  743.0,
#  744.489990234375,
#  755.8300170898438,
#  756.989990234375,
#  759.489990234375,
#  730.1699829101562,
#  739.3800048828125,
#  751.9400024414062,
#  753.6400146484375,
#  774.3900146484375,
#  791.3599853515625,
#  777.5599975585938,
#  781.3099975585938,
#  775.47998046875,
#  775.219970703125,
#  781.530029296875,
#  780.5900268554688,
#  782.75,
#  793.6099853515625,
#  785.489990234375,
#  791.9400024414062,
#  805.719970703125,
#  811.0800170898438,
#  818.3200073242188,
#  843.030029296875,
#  870.1099853515625,
#  864.27001953125,
#  865.7999877929688,
#  894.0,
#  909.6799926757812,
#  1024.8599853515625,
#  1018.4299926757812,
#  1037.8599853515625,
#  1077.0400390625,
#  1114.0,
#  1208.5899658203125,
#  1172.0,
#  1213.8599853515625,
#  1229.9100341796875,
#  1222.0899658203125,
#  1162.93994140625,
#  1023.5,
#  1067.949951171875,
#  1063.510009765625,
#  1033.4200439453125,
#  1013.3900146484376,
#  1054.72998046875,
#  1089.010009765625,
#  1096.3800048828125,
#  1137.06005859375,
#  1156.8699951171875,
#  1109.030029296875,
#  1116.0,
#  1081.9200439453125,
#  1136.989990234375,
#  1144.760009765625,
#  1095.0,
#  1084.5999755859375,
#  1014.969970703125,
#  1009.010009765625,
#  1051.75,
#  1068.9599609375,
#  1003.7999877929688,
#  1017.030029296875,
#  966.4099731445312,
#  958.510009765625,
#  975.989990234375,
#  926.9199829101562,
#  932.5700073242188,
#  899.9400024414062,
#  938.530029296875,
#  1008.8699951171876,
#  1067.0,
#  1093.93994140625,
#  1088.469970703125,
#  1086.18994140625,
#  1070.3399658203125,
#  1056.780029296875,
#  1199.780029296875,
#  1149.5899658203125,
#  1088.1199951171875,
#  1064.699951171875,
#  1026.9599609375,
#  1058.1199951171875,
#  1064.4000244140625,
#  1106.219970703125,
#  1031.56005859375,
#  1049.6099853515625,
#  1030.510009765625,
#  995.6500244140624,
#  996.27001953125,
#  943.9000244140624,
#  930.0,
#  918.4000244140624,
#  937.4099731445312,
#  829.0999755859375,
#  846.3499755859375,
#  936.719970703125,
#  931.25,
#  905.6599731445312,
#  891.1400146484375,
#  923.3200073242188,
#  907.3400268554688,
#  922.0,
#  932.0,
#  904.5499877929688,
#  860.0,
#  875.760009765625,
#  922.4299926757812,
#  923.3900146484376,
#  876.3499755859375,
#  856.97998046875,
#  821.530029296875,
#  764.0399780273438,
#  800.77001953125]

# %%
model=ARIMA(history,order=(1,1,1))

# %%
model=model.fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  698
# Model:                 ARIMA(1, 1, 1)   Log Likelihood               -3479.955
# Date:                Sat, 08 Jul 2023   AIC                           6965.910
# Time:                        11:21:20   BIC                           6979.550
# Sample:                             0   HQIC                          6971.184
#                                 - 698
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9052      0.343      2.640      0.008       0.233       1.577
# ma.L1         -0.9150      0.323     -2.833      0.005      -1.548      -0.282
# sigma2      1270.8611     10.315    123.209      0.000    1250.645    1291.078
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):            250100.69
# Prob(Q):                              0.95   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.65   Skew:                             5.78
# Prob(H) (two-sided):                  0.00   Kurtosis:                        95.08
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
model.forecast()
# Out:
# array([801.74595394])

# %%
test_data[0]
# Out:
# 809.8699951171875

# %%
mean_squared_error([test_data[0]],model.forecast()[0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [100], line 1
# ----> 1 mean_squared_error([test_data[0]],model.forecast()[0])
#
# AttributeError: 'SARIMAX' object has no attribute 'forecast'

# %%
model.forecast()[0]
# Out:
# 801.7459539372896

# %%
def train_arima_model(X, y, arima_order):
    # prepare training dataset
    # make predictions list
    history = [x for x in X]
    predictions = list()
    for t in range(len(y)):
        model = ARIMA(history, order=arima_order)
        model_fit = model.fit()
        yhat = model_fit.forecast()[0]
        predictions.append(yhat)
        history.append(y[t])
    # calculate out of sample error
    rmse = np.sqrt(mean_squared_error(y, predictions))
    return rmse

# %%
# evaluate different combinations of p, d and q values for an ARIMA model to get the best order for ARIMA Model
def evaluate_models(dataset, test, p_values, d_values, q_values):
    dataset = dataset.astype('float32')
    best_score, best_cfg = float("inf"), None
    for p in p_values:
        for d in d_values:
            for q in q_values:
                order = (p,d,q)
                try:
                    rmse = train_arima_model(dataset, test, order)
                    if rmse < best_score:
                        best_score, best_cfg = rmse, order
                    print('ARIMA%s RMSE=%.3f' % (order,rmse))
                except:
                    continue
    print('Best ARIMA%s RMSE=%.3f' % (best_cfg, best_score))

# %%
import warnings
warnings.filterwarnings('ignore')
p_values = range(0, 3)
d_values = range(0, 3)
q_values = range(0, 3)
evaluate_models(train_data, test_data, p_values, d_values, q_values)
# Out:
# ARIMA(0, 0, 0) RMSE=310.377
# ARIMA(0, 0, 1) RMSE=166.981
# ARIMA(0, 0, 2) RMSE=127.775
# ARIMA(0, 1, 0) RMSE=39.516
# ARIMA(0, 1, 1) RMSE=39.506
# ARIMA(0, 1, 2) RMSE=39.586
# ARIMA(0, 2, 0) RMSE=57.835
# ARIMA(0, 2, 1) RMSE=39.602
# ARIMA(0, 2, 2) RMSE=39.600
# ARIMA(1, 0, 0) RMSE=39.451
# ARIMA(1, 0, 1) RMSE=39.447
# ARIMA(1, 0, 2) RMSE=39.513
# ARIMA(1, 1, 0) RMSE=39.505
# ARIMA(1, 1, 1) RMSE=39.488
# ARIMA(1, 1, 2) RMSE=39.599
# ARIMA(1, 2, 0) RMSE=46.206
# ARIMA(1, 2, 1) RMSE=39.599
# ARIMA(1, 2, 2) RMSE=39.681
# ARIMA(2, 0, 0) RMSE=39.446
# ARIMA(2, 0, 1) RMSE=39.599
# ARIMA(2, 0, 2) RMSE=39.446
# ARIMA(2, 1, 0) RMSE=39.586
# ARIMA(2, 1, 1) RMSE=39.578
# ARIMA(2, 1, 2) RMSE=39.526
# ARIMA(2, 2, 0) RMSE=45.576
# ARIMA(2, 2, 1) RMSE=39.686
# ARIMA(2, 2, 2) RMSE=39.657
# Best ARIMA(2, 0, 2) RMSE=39.446

# %%
history=[x for x in train_data]
predictions=list()
conf_list=list()
for t in range(len(test_data)):
    model=ARIMA(history,order=(2,0,2))
    model_fit = model.fit()
    fc = model_fit.forecast(alpha = 0.05)
    predictions.append(fc)
#     conf_list.append(conf)
    history.append(test_data[t])
print("RMSE of ARIMA Model:",np.sqrt(mean_squared_error(test_data,predictions)))
# Out:
# RMSE of ARIMA Model: 39.446378846393046

# %%
plt.figure(figsize=(18,8))
plt.grid(True)
plt.plot(range(len(test_data)),test_data, label = 'True Test Close Value', linewidth = 5)
plt.plot(range(len(predictions)), predictions, label = 'Predictions on test data', linewidth = 5)
plt.xticks(fontsize = 15)
plt.xticks(fontsize = 15)
plt.legend(fontsize = 20, shadow=True,facecolor='lightpink',edgecolor = 'k')
plt.show()

# %%
import statsmodels.api as sm
history=[x for x in train_data]
predictions=list()
conf_list=list()
for t in range(len(test_data)):
    model=sm.tsa.statespace.SARIMAX(history,order=(2,0,2),seasonal_order=(1,1,1,3))
    model_fit=model.fit()
    fc=model_fit.forecast(alpha=0.05)
    predictions.append(fc)
#     conf_list.append(conf)
    history.append(test_data[t])
print("RMSE of ARIMA Model:",np.sqrt(mean_squared_error(test_data,predictions)))
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.06380D+00    |proj g|=  2.43342D-01
#  This problem is unconstrained.
# At iterate    5    f=  5.01910D+00    |proj g|=  4.94891D-02
#
# At iterate   10    f=  4.99075D+00    |proj g|=  1.87517D-02
#
# At iterate   15    f=  4.98836D+00    |proj g|=  1.64849D-02
#
# At iterate   20    f=  4.98756D+00    |proj g|=  2.86885D-02
#
# At iterate   25    f=  4.97636D+00    |proj g|=  4.50784D-02
#
# At iterate   30    f=  4.97620D+00    |proj g|=  6.17483D-04
#
# At iterate   35    f=  4.97618D+00    |proj g|=  1.12747D-02
#
# At iterate   40    f=  4.97610D+00    |proj g|=  3.49105D-03
#
# At iterate   45    f=  4.97601D+00    |proj g|=  6.82935D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     46     57      1     0     0   1.517D-04   4.976D+00
#   F =   4.9760066751012779
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.06346D+00    |proj g|=  2.45645D-01
#
# At iterate    5    f=  5.01857D+00    |proj g|=  4.91694D-02
#  This problem is unconstrained.
# At iterate   10    f=  4.99003D+00    |proj g|=  1.83976D-02
#
# At iterate   15    f=  4.98767D+00    |proj g|=  1.74480D-02
#
# At iterate   20    f=  4.98730D+00    |proj g|=  3.04775D-02
#
# At iterate   25    f=  4.97594D+00    |proj g|=  8.78970D-02
#
# At iterate   30    f=  4.97566D+00    |proj g|=  3.02800D-03
#
# At iterate   35    f=  4.97560D+00    |proj g|=  2.50544D-02
#
# At iterate   40    f=  4.97558D+00    |proj g|=  2.03919D-02
#
# At iterate   45    f=  4.97552D+00    |proj g|=  5.73120D-02
#
# At iterate   50    f=  4.97542D+00    |proj g|=  5.44331D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     50     56      1     0     0   5.443D-02   4.975D+00
#   F =   4.9754173396284296
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.06564D+00    |proj g|=  2.55171D-01
#  This problem is unconstrained.
# At iterate    5    f=  5.02095D+00    |proj g|=  4.63800D-02
#
# At iterate   10    f=  4.99173D+00    |proj g|=  1.67077D-02
#
# At iterate   15    f=  4.98948D+00    |proj g|=  1.88711D-02
#
# At iterate   20    f=  4.98808D+00    |proj g|=  6.40338D-02
#
# At iterate   25    f=  4.97760D+00    |proj g|=  8.35099D-03
#
# At iterate   30    f=  4.97729D+00    |proj g|=  1.97108D-02
#
# At iterate   35    f=  4.97709D+00    |proj g|=  2.22048D-03
#
# At iterate   40    f=  4.97703D+00    |proj g|=  2.02231D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     44     50      1     0     0   7.691D-04   4.977D+00
#   F =   4.9770251350093035
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.06520D+00    |proj g|=  2.57084D-01
#  This problem is unconstrained.
# At iterate    5    f=  5.02045D+00    |proj g|=  4.66649D-02
#
# At iterate   10    f=  4.99116D+00    |proj g|=  1.66602D-02
#
# At iterate   15    f=  4.98893D+00    |proj g|=  1.85431D-02
#
# At iterate   20    f=  4.98230D+00    |proj g|=  6.57700D-01
#
# At iterate   25    f=  4.97678D+00    |proj g|=  2.75024D-02
#
# At iterate   30    f=  4.97655D+00    |proj g|=  4.37065D-02
#
# At iterate   35    f=  4.97650D+00    |proj g|=  1.14120D-02
#
# At iterate   40    f=  4.97643D+00    |proj g|=  5.94996D-03
#
# At iterate   45    f=  4.97640D+00    |proj g|=  9.15785D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     48     57      1     0     0   2.290D-03   4.976D+00
#   F =   4.9763960646286876
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.06441D+00    |proj g|=  2.51452D-01
#  This problem is unconstrained.
# At iterate    5    f=  5.01950D+00    |proj g|=  4.72481D-02
#
# At iterate   10    f=  4.99081D+00    |proj g|=  1.69689D-02
#
# At iterate   15    f=  4.98858D+00    |proj g|=  1.21288D-02
#
# At iterate   20    f=  4.98801D+00    |proj g|=  2.86373D-02
#
# At iterate   25    f=  4.97623D+00    |proj g|=  2.68123D-02
#
# At iterate   30    f=  4.97599D+00    |proj g|=  9.40395D-03
#
# At iterate   35    f=  4.97594D+00    |proj g|=  1.24885D-03
#
# At iterate   40    f=  4.97594D+00    |proj g|=  8.69389D-03
#
# At iterate   45    f=  4.97591D+00    |proj g|=  3.66346D-03
#
# At iterate   50    f=  4.97591D+00    |proj g|=  4.41256D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     50     61      1     0     0   4.413D-04   4.976D+00
#   F =   4.9759120607327052
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.06458D+00    |proj g|=  2.62569D-01
#  This problem is unconstrained.
# At iterate    5    f=  5.01972D+00    |proj g|=  4.59387D-02
#
# At iterate   10    f=  4.99024D+00    |proj g|=  1.61531D-02
#
# At iterate   15    f=  4.98822D+00    |proj g|=  1.39242D-02
#
# At iterate   20    f=  4.98029D+00    |proj g|=  1.36582D-01
#
# At iterate   25    f=  4.97758D+00    |proj g|=  2.62483D-02
#
# At iterate   30    f=  4.97640D+00    |proj g|=  6.23659D-03
#
# At iterate   35    f=  4.97637D+00    |proj g|=  3.93839D-02
#
# At iterate   40    f=  4.97610D+00    |proj g|=  3.26266D-02
#
# At iterate   45    f=  4.97605D+00    |proj g|=  4.15030D-03
#
# At iterate   50    f=  4.97605D+00    |proj g|=  9.86773D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     50     57      1     0     0   9.868D-05   4.976D+00
#   F =   4.9760453887726417
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.06440D+00    |proj g|=  2.64085D-01
#  This problem is unconstrained.
# At iterate    5    f=  5.01923D+00    |proj g|=  4.60386D-02
#
# At iterate   10    f=  4.98954D+00    |proj g|=  1.67975D-02
#
# At iterate   15    f=  4.98721D+00    |proj g|=  1.65071D-02
#
# At iterate   20    f=  4.98001D+00    |proj g|=  4.37009D-01
#
# At iterate   25    f=  4.97580D+00    |proj g|=  2.16962D-02
#
# At iterate   30    f=  4.97552D+00    |proj g|=  3.15124D-02
#
# At iterate   35    f=  4.97548D+00    |proj g|=  3.66914D-02
#
# At iterate   40    f=  4.97541D+00    |proj g|=  2.06058D-02
#
# At iterate   45    f=  4.97539D+00    |proj g|=  1.22036D-02
#
# At iterate   50    f=  4.97538D+00    |proj g|=  7.36575D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     50     57      1     0     0   7.366D-05   4.975D+00
#   F =   4.9753812779715467
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.06404D+00    |proj g|=  2.61947D-01
#  This problem is unconstrained.
# At iterate    5    f=  5.01900D+00    |proj g|=  4.56820D-02
#
# At iterate   10    f=  4.98975D+00    |proj g|=  1.59888D-02
#
# At iterate   15    f=  4.98768D+00    |proj g|=  1.77860D-02
#
# At iterate   20    f=  4.97776D+00    |proj g|=  3.92783D-02
#
# At iterate   25    f=  4.97563D+00    |proj g|=  4.71142D-03
#
# At iterate   30    f=  4.97543D+00    |proj g|=  1.40683D-02
#
# At iterate   35    f=  4.97537D+00    |proj g|=  2.77524D-02
#
# At iterate   40    f=  4.97526D+00    |proj g|=  1.53736D-02
#
# At iterate   45    f=  4.97525D+00    |proj g|=  1.36419D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     46     55      1     0     0   1.679D-04   4.975D+00
#   F =   4.9752519860427089
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.06360D+00    |proj g|=  2.63086D-01
#  This problem is unconstrained.
# At iterate    5    f=  5.01865D+00    |proj g|=  4.55340D-02
#
# At iterate   10    f=  4.98950D+00    |proj g|=  1.62214D-02
#
# At iterate   15    f=  4.98734D+00    |proj g|=  1.82742D-02
#
# At iterate   20    f=  4.97824D+00    |proj g|=  1.22548D+00
#
# At iterate   25    f=  4.97505D+00    |proj g|=  6.80290D-03
#
# At iterate   30    f=  4.97500D+00    |proj g|=  1.33592D-02
#
# At iterate   35    f=  4.97485D+00    |proj g|=  3.22612D-03
#
# At iterate   40    f=  4.97485D+00    |proj g|=  2.13037D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     43     58      1     0     0   2.478D-04   4.975D+00
#   F =   4.9748453257374843
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.06417D+00    |proj g|=  2.68843D-01
#  This problem is unconstrained.
# At iterate    5    f=  5.01874D+00    |proj g|=  4.59013D-02
#
# At iterate   10    f=  4.98897D+00    |proj g|=  1.70090D-02
#
# At iterate   15    f=  4.98682D+00    |proj g|=  5.70723D-03
#
# At iterate   20    f=  4.97693D+00    |proj g|=  7.90691D-01
#
# At iterate   25    f=  4.97487D+00    |proj g|=  7.48271D-03
#
# At iterate   30    f=  4.97483D+00    |proj g|=  6.84137D-03
#
# At iterate   35    f=  4.97479D+00    |proj g|=  3.86562D-02
#
# At iterate   40    f=  4.97469D+00    |proj g|=  3.18161D-03
#
# At iterate   45    f=  4.97467D+00    |proj g|=  3.59410D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     47     56      1     0     0   7.553D-05   4.975D+00
#   F =   4.9746692097445999
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.06327D+00    |proj g|=  2.68128D-01
#  This problem is unconstrained.
# At iterate    5    f=  5.01817D+00    |proj g|=  4.58290D-02
#
# At iterate   10    f=  4.98849D+00    |proj g|=  1.69713D-02
#
# At iterate   15    f=  4.98633D+00    |proj g|=  5.70548D-03
#
# At iterate   20    f=  4.97678D+00    |proj g|=  9.99056D-02
#
# At iterate   25    f=  4.97450D+00    |proj g|=  2.87503D-03
#
# At iterate   30    f=  4.97441D+00    |proj g|=  6.10426D-03
#
# At iterate   35    f=  4.97423D+00    |proj g|=  6.65141D-02
#
# At iterate   40    f=  4.97415D+00    |proj g|=  2.44510D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     41     49      1     0     0   1.077D-03   4.974D+00
#   F =   4.9741469608394997
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.06313D+00    |proj g|=  2.64808D-01
#  This problem is unconstrained.
# At iterate    5    f=  5.01813D+00    |proj g|=  4.58970D-02
#
# At iterate   10    f=  4.98852D+00    |proj g|=  1.60869D-02
#
# At iterate   15    f=  4.98609D+00    |proj g|=  1.26704D-02
#
# At iterate   20    f=  4.98193D+00    |proj g|=  9.73742D-02
#
# At iterate   25    f=  4.97480D+00    |proj g|=  1.89953D-03
#
# At iterate   30    f=  4.97470D+00    |proj g|=  2.51966D-03
#
# At iterate   35    f=  4.97438D+00    |proj g|=  2.73523D-03
#
# At iterate   40    f=  4.97437D+00    |proj g|=  3.32163D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     43     51      1     0     0   8.367D-05   4.974D+00
#   F =   4.9743747924551514
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.06379D+00    |proj g|=  2.74361D-01
#  This problem is unconstrained.
# At iterate    5    f=  5.01858D+00    |proj g|=  4.52184D-02
#
# At iterate   10    f=  4.98897D+00    |proj g|=  3.97752D-02
#
# At iterate   15    f=  4.98700D+00    |proj g|=  7.93217D-03
#
# At iterate   20    f=  4.97933D+00    |proj g|=  9.16836D-02
#
# At iterate   25    f=  4.97240D+00    |proj g|=  2.77516D-01
#
# At iterate   30    f=  4.97029D+00    |proj g|=  6.81376D-03
#
# At iterate   35    f=  4.97023D+00    |proj g|=  2.70729D-04
#
# At iterate   40    f=  4.97023D+00    |proj g|=  3.15514D-03
#
# At iterate   45    f=  4.97022D+00    |proj g|=  1.16139D-03
#
# At iterate   50    f=  4.97022D+00    |proj g|=  6.18113D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     50     61      1     0     0   6.181D-05   4.970D+00
#   F =   4.9702155176757410
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.06339D+00    |proj g|=  2.71353D-01
#  This problem is unconstrained.
# At iterate    5    f=  5.01846D+00    |proj g|=  4.54738D-02
#
# At iterate   10    f=  4.98872D+00    |proj g|=  3.27320D-02
#
# At iterate   15    f=  4.98693D+00    |proj g|=  8.21266D-03
#
# At iterate   20    f=  4.98295D+00    |proj g|=  8.47135D-02
#
# At iterate   25    f=  4.97594D+00    |proj g|=  1.39724D-01
#
# At iterate   30    f=  4.97313D+00    |proj g|=  2.56899D-01
#
# At iterate   35    f=  4.97070D+00    |proj g|=  9.99628D-02
#
# At iterate   40    f=  4.97021D+00    |proj g|=  3.12024D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     42     56      1     0     0   7.731D-06   4.970D+00
#   F =   4.9702016103259377
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.06349D+00    |proj g|=  2.73560D-01
#  This problem is unconstrained.
# At iterate    5    f=  5.01889D+00    |proj g|=  4.51632D-02
#
# At iterate   10    f=  4.98959D+00    |proj g|=  4.30904D-02
#
# At iterate   15    f=  4.98730D+00    |proj g|=  5.79654D-03
#
# At iterate   20    f=  4.98076D+00    |proj g|=  1.98341D-01
#
# At iterate   25    f=  4.97561D+00    |proj g|=  3.58133D-02
#
# At iterate   30    f=  4.97492D+00    |proj g|=  1.22871D-01
#
# At iterate   35    f=  4.97486D+00    |proj g|=  5.68553D-03
#
# At iterate   40    f=  4.97483D+00    |proj g|=  4.85066D-03
#
# At iterate   45    f=  4.97473D+00    |proj g|=  7.25280D-04
#
# At iterate   50    f=  4.97473D+00    |proj g|=  7.80124D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     50     56      1     0     0   7.801D-04   4.975D+00
#   F =   4.9747299149331976
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.06327D+00    |proj g|=  2.82181D-01
#  This problem is unconstrained.
# At iterate    5    f=  5.01871D+00    |proj g|=  4.36008D-02
#
# At iterate   10    f=  4.98969D+00    |proj g|=  3.55331D-02
#
# At iterate   15    f=  4.98690D+00    |proj g|=  6.64879D-03
#
# At iterate   20    f=  4.98506D+00    |proj g|=  2.13685D-02
#
# At iterate   25    f=  4.97475D+00    |proj g|=  6.23569D-03
#
# At iterate   30    f=  4.97471D+00    |proj g|=  8.48089D-03
#
# At iterate   35    f=  4.97458D+00    |proj g|=  6.63117D-02
#
# At iterate   40    f=  4.97448D+00    |proj g|=  3.22833D-03
#
# At iterate   45    f=  4.97448D+00    |proj g|=  2.42521D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     46     53      1     0     0   3.525D-03   4.974D+00
#   F =   4.9744777450441422
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.06401D+00    |proj g|=  2.84328D-01
#  This problem is unconstrained.
# At iterate    5    f=  5.01902D+00    |proj g|=  4.41238D-02
#
# At iterate   10    f=  4.98982D+00    |proj g|=  3.49309D-02
#
# At iterate   15    f=  4.98682D+00    |proj g|=  5.78058D-03
#
# At iterate   20    f=  4.97692D+00    |proj g|=  6.27552D-01
#
# At iterate   25    f=  4.97478D+00    |proj g|=  6.11997D-03
#
# At iterate   30    f=  4.97472D+00    |proj g|=  5.34460D-02
#
# At iterate   35    f=  4.97467D+00    |proj g|=  8.86395D-04
#
# At iterate   40    f=  4.97458D+00    |proj g|=  4.14866D-02
#
# At iterate   45    f=  4.97456D+00    |proj g|=  3.98162D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     46     52      1     0     0   5.834D-04   4.975D+00
#   F =   4.9745557065297170
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.06358D+00    |proj g|=  2.77086D-01
#  This problem is unconstrained.
# At iterate    5    f=  5.01845D+00    |proj g|=  4.56000D-02
#
# At iterate   10    f=  4.98899D+00    |proj g|=  4.74149D-02
#
# At iterate   15    f=  4.98644D+00    |proj g|=  1.03257D-02
#
# At iterate   20    f=  4.97850D+00    |proj g|=  5.27483D-01
#
# At iterate   25    f=  4.97454D+00    |proj g|=  3.09942D-03
#
# At iterate   30    f=  4.97441D+00    |proj g|=  5.86416D-02
#
# At iterate   35    f=  4.97432D+00    |proj g|=  1.37393D-03
#
# At iterate   40    f=  4.97431D+00    |proj g|=  1.39854D-02
#
# At iterate   45    f=  4.97408D+00    |proj g|=  4.01143D-02
#
# At iterate   50    f=  4.97406D+00    |proj g|=  5.18100D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     50     59      1     0     0   5.181D-03   4.974D+00
#   F =   4.9740612788046628
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.06404D+00    |proj g|=  2.52776D-01
#  This problem is unconstrained.
# At iterate    5    f=  5.01913D+00    |proj g|=  4.67029D-02
#
# At iterate   10    f=  4.99057D+00    |proj g|=  1.63802D-02
#
# At iterate   15    f=  4.98841D+00    |proj g|=  1.55669D-02
#
# At iterate   20    f=  4.98805D+00    |proj g|=  3.70742D-02
#
# At iterate   25    f=  4.97663D+00    |proj g|=  4.85684D-02
#
# At iterate   30    f=  4.97616D+00    |proj g|=  2.12438D-03
#
# At iterate   35    f=  4.97613D+00    |proj g|=  3.92913D-03
#
# At iterate   40    f=  4.97609D+00    |proj g|=  4.10762D-03
#
# At iterate   45    f=  4.97605D+00    |proj g|=  4.90761D-03
#
# At iterate   50    f=  4.97598D+00    |proj g|=  7.17430D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     50     57      1     0     0   7.174D-03   4.976D+00
#   F =   4.9759801574443463
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.06383D+00    |proj g|=  2.54170D-01
#  This problem is unconstrained.
# At iterate    5    f=  5.01860D+00    |proj g|=  4.68162D-02
#
# At iterate   10    f=  4.98995D+00    |proj g|=  1.67575D-02
#
# At iterate   15    f=  4.98774D+00    |proj g|=  1.71895D-02
#
# At iterate   20    f=  4.98744D+00    |proj g|=  4.11655D-02
#
# At iterate   25    f=  4.97828D+00    |proj g|=  2.62214D-01
#
# At iterate   30    f=  4.97638D+00    |proj g|=  3.24932D-03
#
# At iterate   35    f=  4.97577D+00    |proj g|=  2.21344D-01
#
# At iterate   40    f=  4.97534D+00    |proj g|=  1.16014D-02
#
# At iterate   45    f=  4.97533D+00    |proj g|=  2.54099D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     46     52      1     0     0   1.654D-04   4.975D+00
#   F =   4.9753304353568941
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.06372D+00    |proj g|=  2.54069D-01
#  This problem is unconstrained.
# At iterate    5    f=  5.01814D+00    |proj g|=  4.72135D-02
#
# At iterate   10    f=  4.98975D+00    |proj g|=  1.75765D-02
#
# At iterate   15    f=  4.98738D+00    |proj g|=  2.05208D-02
#
# At iterate   20    f=  4.98709D+00    |proj g|=  3.93992D-02
#
# At iterate   25    f=  4.97765D+00    |proj g|=  1.72894D-01
#
# At iterate   30    f=  4.97526D+00    |proj g|=  1.77067D-01
#
# At iterate   35    f=  4.97516D+00    |proj g|=  1.04943D-02
#
# At iterate   40    f=  4.97490D+00    |proj g|=  2.61479D-03
#
# At iterate   45    f=  4.97488D+00    |proj g|=  4.01730D-03
#
# At iterate   50    f=  4.97483D+00    |proj g|=  2.45676D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     50     62      1     0     0   2.457D-02   4.975D+00
#   F =   4.9748277292309240
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.06310D+00    |proj g|=  2.54946D-01
#  This problem is unconstrained.
# At iterate    5    f=  5.01760D+00    |proj g|=  4.70097D-02
#
# At iterate   10    f=  4.98903D+00    |proj g|=  1.75765D-02
#
# At iterate   15    f=  4.98664D+00    |proj g|=  2.07586D-02
#
# At iterate   20    f=  4.98639D+00    |proj g|=  3.17619D-02
#
# At iterate   25    f=  4.97631D+00    |proj g|=  5.66283D-02
#
# At iterate   30    f=  4.97480D+00    |proj g|=  2.54697D-03
#
# At iterate   35    f=  4.97436D+00    |proj g|=  1.04241D-02
#
# At iterate   40    f=  4.97435D+00    |proj g|=  8.10632D-03
#
# At iterate   45    f=  4.97435D+00    |proj g|=  2.17361D-02
#
# At iterate   50    f=  4.97428D+00    |proj g|=  9.58798D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     50     56      1     0     0   9.588D-02   4.974D+00
#   F =   4.9742825523129417
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.06639D+00    |proj g|=  2.45661D-01
#  This problem is unconstrained.
# At iterate    5    f=  5.02008D+00    |proj g|=  4.90813D-02
#
# At iterate   10    f=  4.99324D+00    |proj g|=  2.44468D-02
#
# At iterate   15    f=  4.99027D+00    |proj g|=  1.32843D-02
#
# At iterate   20    f=  4.98970D+00    |proj g|=  3.50382D-02
#
# At iterate   25    f=  4.97762D+00    |proj g|=  6.81910D-03
#
# At iterate   30    f=  4.97754D+00    |proj g|=  3.83144D-03
#
# At iterate   35    f=  4.97738D+00    |proj g|=  4.50929D-02
#
# At iterate   40    f=  4.97732D+00    |proj g|=  6.72492D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     44     52      1     0     0   1.695D-05   4.977D+00
#   F =   4.9773181231081214
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.06639D+00    |proj g|=  2.41880D-01
#  This problem is unconstrained.
# At iterate    5    f=  5.01947D+00    |proj g|=  5.50238D-02
#
# At iterate   10    f=  4.99339D+00    |proj g|=  2.81109D-02
#
# At iterate   15    f=  4.98980D+00    |proj g|=  1.45816D-02
#
# At iterate   20    f=  4.98857D+00    |proj g|=  5.33624D-03
#
# At iterate   25    f=  4.97755D+00    |proj g|=  2.87723D-01
#
# At iterate   30    f=  4.97690D+00    |proj g|=  4.78598D-03
#
# At iterate   35    f=  4.97683D+00    |proj g|=  4.72631D-02
#
# At iterate   40    f=  4.97682D+00    |proj g|=  3.70793D-03
#
# At iterate   45    f=  4.97682D+00    |proj g|=  3.06809D-03
#
# At iterate   50    f=  4.97680D+00    |proj g|=  2.34842D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     50     57      1     0     0   2.348D-02   4.977D+00
#   F =   4.9768015092054885
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.06538D+00    |proj g|=  2.42070D-01
#  This problem is unconstrained.
# At iterate    5    f=  5.01877D+00    |proj g|=  5.16645D-02
#
# At iterate   10    f=  4.99257D+00    |proj g|=  2.65475D-02
#
# At iterate   15    f=  4.98924D+00    |proj g|=  1.32204D-02
#
# At iterate   20    f=  4.98828D+00    |proj g|=  1.55202D-02
#
# At iterate   25    f=  4.97654D+00    |proj g|=  1.80794D-02
#
# At iterate   30    f=  4.97623D+00    |proj g|=  8.91812D-03
#
# At iterate   35    f=  4.97619D+00    |proj g|=  2.42078D-03
#
# At iterate   40    f=  4.97611D+00    |proj g|=  3.51051D-03
#
# At iterate   45    f=  4.97608D+00    |proj g|=  2.81432D-03
#
# At iterate   50    f=  4.97608D+00    |proj g|=  1.38053D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     50     61      1     0     0   1.381D-03   4.976D+00
#   F =   4.9760766943526100
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.06459D+00    |proj g|=  2.43565D-01
#  This problem is unconstrained.
# At iterate    5    f=  5.01833D+00    |proj g|=  4.97872D-02
#
# At iterate   10    f=  4.99180D+00    |proj g|=  2.49138D-02
#
# At iterate   15    f=  4.98865D+00    |proj g|=  1.29317D-02
#
# At iterate   20    f=  4.98793D+00    |proj g|=  1.99869D-02
#
# At iterate   25    f=  4.97664D+00    |proj g|=  7.53446D-02
#
# At iterate   30    f=  4.97570D+00    |proj g|=  3.14758D-02
#
# At iterate   35    f=  4.97565D+00    |proj g|=  3.66106D-03
#
# At iterate   40    f=  4.97560D+00    |proj g|=  3.12238D-02
#
# At iterate   45    f=  4.97555D+00    |proj g|=  1.18526D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     49     59      1     0     0   6.545D-04   4.976D+00
#   F =   4.9755437263977749
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.06417D+00    |proj g|=  2.41174D-01
#  This problem is unconstrained.
# At iterate    5    f=  5.01759D+00    |proj g|=  5.28058D-02
#
# At iterate   10    f=  4.99171D+00    |proj g|=  2.80662D-02
#
# At iterate   15    f=  4.98817D+00    |proj g|=  1.53697D-02
#
# At iterate   20    f=  4.98536D+00    |proj g|=  1.91258D-02
#
# At iterate   25    f=  4.97529D+00    |proj g|=  1.86518D-01
#
# At iterate   30    f=  4.97513D+00    |proj g|=  1.51699D-02
#
# At iterate   35    f=  4.97506D+00    |proj g|=  4.71270D-03
#
# At iterate   40    f=  4.97504D+00    |proj g|=  2.77342D-02
#
# At iterate   45    f=  4.97491D+00    |proj g|=  9.37078D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     47     53      1     0     0   7.704D-04   4.975D+00
#   F =   4.9749120055633460
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.06602D+00    |proj g|=  2.38321D-01
#
# At iterate    5    f=  5.01862D+00    |proj g|=  5.89396D-02
#  This problem is unconstrained.
# At iterate   10    f=  4.99337D+00    |proj g|=  3.22946D-02
#
# At iterate   15    f=  4.98894D+00    |proj g|=  3.49892D-02
#
# At iterate   20    f=  4.98814D+00    |proj g|=  4.27814D-02
#
# At iterate   25    f=  4.97605D+00    |proj g|=  6.31099D-04
#
# At iterate   30    f=  4.97604D+00    |proj g|=  2.90928D-03
#
# At iterate   35    f=  4.97603D+00    |proj g|=  3.64564D-02
#
# At iterate   40    f=  4.97593D+00    |proj g|=  1.07231D-03
#
# At iterate   45    f=  4.97593D+00    |proj g|=  5.22587D-03
#
# At iterate   50    f=  4.97593D+00    |proj g|=  1.92579D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     50     59      1     0     0   1.926D-03   4.976D+00
#   F =   4.9759316943415604
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.06612D+00    |proj g|=  2.32143D-01
#  This problem is unconstrained.
# At iterate    5    f=  5.01884D+00    |proj g|=  6.09173D-02
#
# At iterate   10    f=  4.99420D+00    |proj g|=  3.46387D-02
#
# At iterate   15    f=  4.98989D+00    |proj g|=  8.22020D-03
#
# At iterate   20    f=  4.98012D+00    |proj g|=  1.66243D-01
#
# At iterate   25    f=  4.97691D+00    |proj g|=  3.51064D-03
#
# At iterate   30    f=  4.97689D+00    |proj g|=  3.52560D-03
#
# At iterate   35    f=  4.97689D+00    |proj g|=  8.83089D-03
#
# At iterate   40    f=  4.97687D+00    |proj g|=  5.36095D-02
#
# At iterate   45    f=  4.97682D+00    |proj g|=  7.38404D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     49     59      1     0     0   8.373D-05   4.977D+00
#   F =   4.9768185725158629
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.06557D+00    |proj g|=  2.23394D-01
#  This problem is unconstrained.
# At iterate    5    f=  5.01837D+00    |proj g|=  6.56026D-02
#
# At iterate   10    f=  4.99432D+00    |proj g|=  3.69587D-02
#
# At iterate   15    f=  4.99006D+00    |proj g|=  5.87447D-03
#
# At iterate   20    f=  4.98774D+00    |proj g|=  6.68033D-02
#
# At iterate   25    f=  4.97756D+00    |proj g|=  2.44430D-02
#
# At iterate   30    f=  4.97743D+00    |proj g|=  5.65335D-02
#
# At iterate   35    f=  4.97739D+00    |proj g|=  3.15640D-02
#
# At iterate   40    f=  4.97731D+00    |proj g|=  4.54906D-02
#
# At iterate   45    f=  4.97718D+00    |proj g|=  1.92031D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     46     54      1     0     0   8.811D-05   4.977D+00
#   F =   4.9771791305069861
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.06491D+00    |proj g|=  2.28027D-01
#  This problem is unconstrained.
# At iterate    5    f=  5.01793D+00    |proj g|=  5.70768D-02
#
# At iterate   10    f=  4.99320D+00    |proj g|=  3.34219D-02
#
# At iterate   15    f=  4.98931D+00    |proj g|=  7.61709D-03
#
# At iterate   20    f=  4.98706D+00    |proj g|=  1.07978D-01
#
# At iterate   25    f=  4.97694D+00    |proj g|=  1.30973D-01
#
# At iterate   30    f=  4.97681D+00    |proj g|=  5.28202D-02
#
# At iterate   35    f=  4.97672D+00    |proj g|=  6.75240D-03
#
# At iterate   40    f=  4.97671D+00    |proj g|=  2.94857D-02
#
# At iterate   45    f=  4.97659D+00    |proj g|=  1.04432D-01
#
# At iterate   50    f=  4.97656D+00    |proj g|=  5.85835D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     50     57      1     0     0   5.858D-03   4.977D+00
#   F =   4.9765620402924586
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.06472D+00    |proj g|=  2.26902D-01
#  This problem is unconstrained.
# At iterate    5    f=  5.01777D+00    |proj g|=  6.00091D-02
#
# At iterate   10    f=  4.99324D+00    |proj g|=  3.51572D-02
#
# At iterate   15    f=  4.98908D+00    |proj g|=  5.84850D-03
#
# At iterate   20    f=  4.98739D+00    |proj g|=  7.59882D-03
#
# At iterate   25    f=  4.97667D+00    |proj g|=  9.58503D-02
#
# At iterate   30    f=  4.97657D+00    |proj g|=  7.47750D-02
#
# At iterate   35    f=  4.97645D+00    |proj g|=  1.40581D-03
#
# At iterate   40    f=  4.97645D+00    |proj g|=  6.14549D-03
#
# At iterate   45    f=  4.97641D+00    |proj g|=  7.59945D-02
#
# At iterate   50    f=  4.97635D+00    |proj g|=  1.24065D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     50     59      1     0     0   1.241D-03   4.976D+00
#   F =   4.9763530657594419
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.06527D+00    |proj g|=  2.23281D-01
#  This problem is unconstrained.
# At iterate    5    f=  5.01757D+00    |proj g|=  7.04212D-02
#
# At iterate   10    f=  4.99383D+00    |proj g|=  3.73897D-02
#
# At iterate   15    f=  4.98946D+00    |proj g|=  5.87137D-03
#
# At iterate   20    f=  4.98679D+00    |proj g|=  1.54240D-02
#
# At iterate   25    f=  4.97740D+00    |proj g|=  5.79840D-02
#
# At iterate   30    f=  4.97715D+00    |proj g|=  7.48759D-02
#
# At iterate   35    f=  4.97690D+00    |proj g|=  8.54584D-03
#
# At iterate   40    f=  4.97689D+00    |proj g|=  6.88991D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     44     54      1     0     0   2.024D-04   4.977D+00
#   F =   4.9768933495164012
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.06458D+00    |proj g|=  2.16123D-01
#  This problem is unconstrained.
# At iterate    5    f=  5.01610D+00    |proj g|=  8.48894D-02
#
# At iterate   10    f=  4.99317D+00    |proj g|=  3.46541D-02
#
# At iterate   15    f=  4.98871D+00    |proj g|=  2.45757D-02
#
# At iterate   20    f=  4.98681D+00    |proj g|=  1.14882D-01
#
# At iterate   25    f=  4.97757D+00    |proj g|=  1.00473D-01
#
# At iterate   30    f=  4.97666D+00    |proj g|=  2.71229D-03
#
# At iterate   35    f=  4.97664D+00    |proj g|=  4.77855D-03
#
# At iterate   40    f=  4.97634D+00    |proj g|=  4.45023D-02
#
# At iterate   45    f=  4.97623D+00    |proj g|=  2.62474D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     49     60      1     0     0   7.372D-04   4.976D+00
#   F =   4.9762322707214324
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# ...
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     50     57      1     0     0   5.299D-02   4.980D+00
#   F =   4.9800928940197515
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.07422D+00    |proj g|=  2.57728D-01
#  This problem is unconstrained.
# At iterate    5    f=  5.02505D+00    |proj g|=  4.69372D-02
#
# At iterate   10    f=  4.99792D+00    |proj g|=  2.02412D-02
#
# At iterate   15    f=  4.99527D+00    |proj g|=  1.28534D-02
#
# At iterate   20    f=  4.99454D+00    |proj g|=  3.20078D-02
#
# At iterate   25    f=  4.98444D+00    |proj g|=  4.30638D-01
#
# At iterate   30    f=  4.98330D+00    |proj g|=  1.88027D-02
#
# At iterate   35    f=  4.98316D+00    |proj g|=  2.78006D-02
#
# At iterate   40    f=  4.98285D+00    |proj g|=  7.75456D-02
#
# At iterate   45    f=  4.98271D+00    |proj g|=  1.99351D-03
#
# At iterate   50    f=  4.98271D+00    |proj g|=  5.11953D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     50     59      1     0     0   5.120D-04   4.983D+00
#   F =   4.9827109176546722
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.07400D+00    |proj g|=  2.47928D-01
#  This problem is unconstrained.
# At iterate    5    f=  5.02401D+00    |proj g|=  5.80966D-02
#
# At iterate   10    f=  4.99797D+00    |proj g|=  2.55590D-02
#
# At iterate   15    f=  4.99469D+00    |proj g|=  1.18022D-02
#
# At iterate   20    f=  4.99388D+00    |proj g|=  4.74897D-02
#
# At iterate   25    f=  4.98586D+00    |proj g|=  1.45800D-02
#
# At iterate   30    f=  4.98564D+00    |proj g|=  1.47119D-02
#
# At iterate   35    f=  4.98549D+00    |proj g|=  2.61938D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     39     48      1     0     0   2.733D-04   4.985D+00
#   F =   4.9854844421902111
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.07520D+00    |proj g|=  2.56416D-01
#  This problem is unconstrained.
# At iterate    5    f=  5.02677D+00    |proj g|=  4.50498D-02
#
# At iterate   10    f=  5.00037D+00    |proj g|=  1.70503D-02
#
# At iterate   15    f=  4.99803D+00    |proj g|=  1.44568D-02
#
# At iterate   20    f=  4.99528D+00    |proj g|=  1.00823D-01
#
# At iterate   25    f=  4.98118D+00    |proj g|=  1.26716D-02
#
# At iterate   30    f=  4.98066D+00    |proj g|=  4.24274D-04
#
# At iterate   35    f=  4.98066D+00    |proj g|=  1.39967D-03
#
# At iterate   40    f=  4.98064D+00    |proj g|=  1.05002D-02
#
# At iterate   45    f=  4.98063D+00    |proj g|=  2.60695D-03
#
# At iterate   50    f=  4.98063D+00    |proj g|=  9.93405D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     50     56      1     0     0   9.934D-04   4.981D+00
#   F =   4.9806300070402658
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.07494D+00    |proj g|=  2.56918D-01
#  This problem is unconstrained.
# At iterate    5    f=  5.02632D+00    |proj g|=  4.61814D-02
#
# At iterate   10    f=  5.00000D+00    |proj g|=  1.92776D-02
#
# At iterate   15    f=  4.99744D+00    |proj g|=  1.33910D-02
#
# At iterate   20    f=  4.99556D+00    |proj g|=  6.82028D-02
#
# At iterate   25    f=  4.98521D+00    |proj g|=  1.28686D-01
#
# At iterate   30    f=  4.98510D+00    |proj g|=  1.77991D-02
#
# At iterate   35    f=  4.98492D+00    |proj g|=  3.53262D-03
#
# At iterate   40    f=  4.98491D+00    |proj g|=  1.08709D-02
#
# At iterate   45    f=  4.98473D+00    |proj g|=  7.92601D-03
#
# At iterate   50    f=  4.98461D+00    |proj g|=  5.92983D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     50     57      1     0     0   5.930D-02   4.985D+00
#   F =   4.9846089183689708
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.07563D+00    |proj g|=  2.42405D-01
#  This problem is unconstrained.
# At iterate    5    f=  5.02541D+00    |proj g|=  6.09755D-02
#
# At iterate   10    f=  5.00182D+00    |proj g|=  2.96558D-02
#
# At iterate   15    f=  4.99805D+00    |proj g|=  8.20167D-02
#
# At iterate   20    f=  4.98947D+00    |proj g|=  1.27094D+00
#
# At iterate   25    f=  4.98619D+00    |proj g|=  9.43980D-03
#
# At iterate   30    f=  4.98609D+00    |proj g|=  1.67321D-03
#
# At iterate   35    f=  4.98609D+00    |proj g|=  1.04425D-02
#
# At iterate   40    f=  4.98604D+00    |proj g|=  5.67672D-02
#
# At iterate   45    f=  4.98591D+00    |proj g|=  2.79277D-02
#
# At iterate   50    f=  4.98588D+00    |proj g|=  1.23904D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     50     56      1     0     0   1.239D-02   4.986D+00
#   F =   4.9858826164606800
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.07527D+00    |proj g|=  2.39922D-01
#  This problem is unconstrained.
# At iterate    5    f=  5.02474D+00    |proj g|=  6.09708D-02
#
# At iterate   10    f=  5.00140D+00    |proj g|=  3.15119D-02
#
# At iterate   15    f=  4.99827D+00    |proj g|=  5.86869D-03
#
# At iterate   20    f=  4.99565D+00    |proj g|=  2.00004D-02
#
# At iterate   25    f=  4.98585D+00    |proj g|=  8.17573D-03
#
# At iterate   30    f=  4.98574D+00    |proj g|=  2.50792D-03
#
# At iterate   35    f=  4.98558D+00    |proj g|=  1.19593D-01
#
# At iterate   40    f=  4.98528D+00    |proj g|=  3.51666D-03
#
# At iterate   45    f=  4.98527D+00    |proj g|=  1.00294D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     49     58      1     0     0   1.731D-04   4.985D+00
#   F =   4.9852746659007012
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.07581D+00    |proj g|=  2.45784D-01
#  This problem is unconstrained.
# At iterate    5    f=  5.02498D+00    |proj g|=  5.59263D-02
#
# At iterate   10    f=  5.00113D+00    |proj g|=  2.79346D-02
#
# At iterate   15    f=  4.99795D+00    |proj g|=  1.71647D-02
#
# At iterate   20    f=  4.99160D+00    |proj g|=  8.45178D-02
#
# At iterate   25    f=  4.98579D+00    |proj g|=  1.75515D-02
#
# At iterate   30    f=  4.98576D+00    |proj g|=  2.28197D-02
#
# At iterate   35    f=  4.98575D+00    |proj g|=  5.26760D-04
#
# At iterate   40    f=  4.98575D+00    |proj g|=  1.41577D-03
#
# At iterate   45    f=  4.98565D+00    |proj g|=  1.23121D-01
#
# At iterate   50    f=  4.98556D+00    |proj g|=  4.29464D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     50     59      1     0     0   4.295D-03   4.986D+00
#   F =   4.9855621837951931
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.07608D+00    |proj g|=  2.47932D-01
#  This problem is unconstrained.
# At iterate    5    f=  5.02515D+00    |proj g|=  5.35559D-02
#
# At iterate   10    f=  5.00103D+00    |proj g|=  2.61423D-02
#
# At iterate   15    f=  4.99763D+00    |proj g|=  8.78280D-03
#
# At iterate   20    f=  4.98694D+00    |proj g|=  5.19701D-01
#
# At iterate   25    f=  4.98628D+00    |proj g|=  1.31041D-02
#
# At iterate   30    f=  4.98621D+00    |proj g|=  1.01574D-02
#
# At iterate   35    f=  4.98612D+00    |proj g|=  2.44429D-01
#
# At iterate   40    f=  4.98580D+00    |proj g|=  1.79750D-02
#
# At iterate   45    f=  4.98578D+00    |proj g|=  1.61174D-02
#
# At iterate   50    f=  4.98574D+00    |proj g|=  1.39824D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     50     55      1     0     0   1.398D-02   4.986D+00
#   F =   4.9857437526805803
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.07540D+00    |proj g|=  2.46945D-01
#  This problem is unconstrained.
# At iterate    5    f=  5.02509D+00    |proj g|=  5.69948D-02
#
# At iterate   10    f=  5.00078D+00    |proj g|=  2.71199D-02
#
# At iterate   15    f=  4.99775D+00    |proj g|=  5.78514D-03
#
# At iterate   20    f=  4.99548D+00    |proj g|=  9.08590D-02
#
# At iterate   25    f=  4.98691D+00    |proj g|=  3.44394D-02
#
# At iterate   30    f=  4.98628D+00    |proj g|=  3.58800D-03
#
# At iterate   35    f=  4.98590D+00    |proj g|=  8.15478D-02
#
# At iterate   40    f=  4.98566D+00    |proj g|=  4.33169D-04
#
# At iterate   45    f=  4.98566D+00    |proj g|=  6.79626D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     45     54      1     0     0   6.796D-04   4.986D+00
#   F =   4.9856566208163358
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.07796D+00    |proj g|=  2.61022D-01
#  This problem is unconstrained.
# At iterate    5    f=  5.02721D+00    |proj g|=  4.79001D-02
#
# At iterate   10    f=  5.00160D+00    |proj g|=  2.18829D-02
#
# At iterate   15    f=  4.99919D+00    |proj g|=  7.93050D-03
#
# At iterate   20    f=  4.99280D+00    |proj g|=  6.29134D-02
#
# At iterate   25    f=  4.98977D+00    |proj g|=  2.89372D-03
#
# At iterate   30    f=  4.98969D+00    |proj g|=  2.31898D-03
#
# At iterate   35    f=  4.98969D+00    |proj g|=  2.31475D-02
#
# At iterate   40    f=  4.98965D+00    |proj g|=  7.81182D-03
#
# At iterate   45    f=  4.98953D+00    |proj g|=  5.85008D-02
#
# At iterate   50    f=  4.98950D+00    |proj g|=  4.12759D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     50     59      1     0     0   4.128D-03   4.990D+00
#   F =   4.9895007562498961
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.07689D+00    |proj g|=  2.56059D-01
#  This problem is unconstrained.
# At iterate    5    f=  5.02635D+00    |proj g|=  5.13640D-02
#
# At iterate   10    f=  5.00111D+00    |proj g|=  2.41332D-02
#
# At iterate   15    f=  4.99854D+00    |proj g|=  7.88991D-03
#
# At iterate   20    f=  4.99166D+00    |proj g|=  2.89095D-01
#
# At iterate   25    f=  4.98633D+00    |proj g|=  7.55401D-03
#
# At iterate   30    f=  4.98627D+00    |proj g|=  8.82192D-03
#
# At iterate   35    f=  4.98625D+00    |proj g|=  1.79991D-02
#
# At iterate   40    f=  4.98600D+00    |proj g|=  1.51620D-01
#
# At iterate   45    f=  4.98580D+00    |proj g|=  2.06036D-03
#
# At iterate   50    f=  4.98580D+00    |proj g|=  1.66696D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     50     56      1     0     0   1.667D-03   4.986D+00
#   F =   4.9857960404085508
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RMSE of ARIMA Model: 40.2050696943694

# %%
plt.figure(figsize=(18,8))
plt.title('Forecast vs Actual', fontsize = 25)
plt.plot(range(60), predictions, label = 'Predictions', linewidth = 4)
plt.plot(range(60), test_data, label = 'Close', linewidth = 4)
plt.legend(fontsize = 25, shadow=True,facecolor='lightpink',edgecolor = 'k')

# %%
result=model_fit.get_prediction(start=1,end=len(df_close)+365,ax=ax1)
confidence_interval = pred.conf_int()

# %%
pred=result.predicted_mean

# %%
plt.figure()
plt.plot(univariate_data["Date"][1:len(df_close)], label='Actual')
plt.plot(univariate_data["Date"][1:len(df_close)+60], pred, color='red', label='Predicted')
plt.fill_between(dates[start_index:end_index], confidence_interval[:, 0], confidence_interval[:, 1], color='pink', alpha=0.05, label='Confidence Interval')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [128], line 3
#       1 plt.figure()
#       2 plt.plot(univariate_data["Date"][1:len(df_close)], label='Actual')
# ----> 3 plt.plot(univariate_data["Date"][1:len(df_close)+60], pred, color='red', label='Predicted')
#       4 plt.fill_between(dates[start_index:end_index], confidence_interval[:, 0], confidence_interval[:, 1], color='pink', alpha=0.05, label='Confidence Interval')
#       5 plt.legend()
#
# File ~/anaconda3/envs/jidoka_env/lib/python3.10/site-packages/matplotlib/pyplot.py:2748, in plot(scalex, scaley, data, *args, **kwargs)
#    2746 @_copy_docstring_and_deprecators(Axes.plot)
#    2747 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2748     return gca().plot(
#    2749         *args, scalex=scalex, scaley=scaley,
#    2750         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~/anaconda3/envs/jidoka_env/lib/python3.10/site-packages/matplotlib/axes/_axes.py:1668, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1425 """
#    1426 Plot y versus x as lines and/or markers.
#    1427
#    (...)
#    1665 (``'green'``) or hex strings (``'#008000'``).
#    1666 """
#    1667 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1668 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1669 for line in lines:
#    1670     self.add_line(line)
#
# File ~/anaconda3/envs/jidoka_env/lib/python3.10/site-packages/matplotlib/axes/_base.py:311, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     309     this += args[0],
#     310     args = args[1:]
# --> 311 yield from self._plot_args(
#     312     this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File ~/anaconda3/envs/jidoka_env/lib/python3.10/site-packages/matplotlib/axes/_base.py:504, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     501     self.axes.yaxis.update_units(y)
#     503 if x.shape[0] != y.shape[0]:
# --> 504     raise ValueError(f"x and y must have same first dimension, but "
#     505                      f"have shapes {x.shape} and {y.shape}")
#     506 if x.ndim > 2 or y.ndim > 2:
#     507     raise ValueError(f"x and y can be no greater than 2D, but have "
#     508                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (757,) and (1123,)
